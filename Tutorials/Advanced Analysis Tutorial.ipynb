# %% [markdown]
# # Advanced Analysis Tutorial: Neuroepithelial Organoid Pipeline
#
# ## ✨ Introduction
#
# In this tutorial, we introduce two new features added to the Neuroepithelial Organoid Analysis Pipeline:
# - Highlighting the most typical Apical-out cells (top 10% most centralized based on distance ratio)
# - Visualizing the distribution of cell sizes through histograms
#
# These enhancements provide deeper insights into the morphology and polarity of neuroepithelial organoids.
#
# ---
#
# ### 🛠️ Setup
#
# ### Environment Setup
#
# Make sure you have installed the required packages:
#
# ```bash
# python3 -m venv .venv
# source .venv/bin/activate
# pip install -r requirements.txt

# %% [markdown]
# ## 🚀 How to Run the Updated Pipeline
#
# ### 1. Project Structure
#
# Make sure your project structure looks like this:
#
# ```
# src/
# ├── main.py               # Main script
# ├── noa/                  # Supporting modules
# ├── image/                # Image processing modules
# ├── advanced/             # New advanced analysis modules
# │   ├── __init__.py
# │   ├── highlight.py      # Highlight typical Apical-out cells
# │   └── histogram.py      # Plot cell size histogram
# ```
#
# ✅ Confirm that `highlight.py` and `histogram.py` are complete and properly imported in `main.py`:
#
# ```python
# from advanced.highlight import highlight_typical_cells
# from advanced.histogram import plot_area_histogram
# ```
#
# ---
#
# ### 2. Prepare Input Images
#
# - Gather your input images (`.png`, `.tif`, `.jpg`, etc.).
# - Place them in a known folder, e.g.,
#   ```
#   ~/Desktop/test_images/
#   ```
#
# ✅ Ensure image filenames are clean (preferably English letters and numbers, no spaces or special characters).
#
# ---
#
# ### 3. Configure Image Files
#
# In `main.py`, manually define the images you want to process:
#
# ```python
# image_files = {
#     "Sample_A": "/Users/yourname/Desktop/test_images/Sample_A.png",
#     "Sample_B": "/Users/yourname/Desktop/test_images/Sample_B.png"
# }
# ```
#
# ✅ Make sure the paths and filenames are correct.
#
# ---
#
# ### 4. Activate the Python Virtual Environment
#
# If you already have `.venv/`, activate it:
#
# ```bash
# source .venv/bin/activate
# ```
#
# If not, create and set up a virtual environment:
#
# ```bash
# python3 -m venv .venv
# source .venv/bin/activate
# pip install -r requirements.txt
# ```
#
# ✅ Install the required libraries: `numpy`, `scipy`, `pandas`, `scikit-image`, `matplotlib`.
#
# ---
#
# ### 5. Run the Main Script
#
# In your `src/` directory, run:
#
# ```bash
# python main.py
# ```
#
# ✅ The script will automatically process all images listed in `image_files`.
#
# ---
#
# ### 6. Outputs
#
# After successful execution, you will find the following files saved on your Desktop:
#
# | Output | Description |
# |:---|:---|
# | `Sample_A_analysis.png` | Overlay image showing normal Apical-out cells (blue) and top 10% typical Apical-out cells (gold) |
# | `Sample_A_area_histogram.png` | Histogram of detected cell sizes |
# | `updated_cell_analysis.xlsx` | Excel file summarizing cell properties and convex hull measurements |
#
# ✅ You can open and inspect each file to verify the results!
#
# ---
#
# ### 🎯 Quick Checklist
#
# | Step | What to Check |
# |:---|:---|
# | Project Structure | `src/advanced/` exists and is correctly organized |
# | Input Images | Paths are correct and images are cleanly named |
# | Virtual Environment | Activated and all dependencies installed |
# | Run Script | `python main.py` completes without errors |
# | Output Files | Overlay images, histograms, and Excel file appear on Desktop |
